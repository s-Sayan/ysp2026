# %%
from superbit_lensing.plotter import pub_rc, plot_rs_wl_overlay


import matplotlib.pyplot as plt
plt.rcParams.update(pub_rc(fontsize=25))

fig, ax = plot_rs_wl_overlay(
    rs_file="/home/saysaha/kappa_maps/Abell1689/rs/redseq_Abell1689_number_map.fits",
    wl_file="/home/saysaha/kappa_maps/Abell1689/ks/snr_ks_Abell1689_b.fits",
    ra_range=(197.80, 197.94),
    dec_range=(-1.41, -1.27),
    contour_start=2.,
    contour_step=0.5,
    cmap="turbo",
    label="Abell 1689",
    redshift=0.1832,
    outfile="abell1689_rs_number_wl.pdf",
    dpi=300,
    figsize=(9,9)
)
plt.show()
